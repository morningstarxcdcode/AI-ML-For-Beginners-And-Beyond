# %% [markdown]
# {
#  "cells": [
#   {
#    "cell_type": "markdown",
#    "metadata": {},
#    "source": [
#     "# 🧬 AI in Healthcare: Predicting Diabetes from Health Metrics\n",
#     "\n",
#     "Train a model to predict whether a patient has diabetes based on health metrics.\n",
#     "\n",
#     "### 🎯 Objective:\n",
#     "- Build a Decision Tree Classifier to predict diabetes.\n",
#     "- Evaluate the model's performance using accuracy."
#    ]
#   },
#   {
#    "cell_type": "code",
#    "execution_count": null,
#    "metadata": {},
#    "outputs": [],
#    "source": [
#     "# Step 1: Import necessary libraries\n",
#     "import pandas as pd\n",
#     "from sklearn.tree import DecisionTreeClassifier\n",
#     "from sklearn.model_selection import train_test_split\n",
#     "from sklearn.metrics import accuracy_score"
#    ]
#   },
#   {
#    "cell_type": "code",
#    "execution_count": null,
#    "metadata": {},
#    "outputs": [],
#    "source": [
#     "# Step 2: Create a dummy dataset (mocked for demo)\n",
#     "# This dataset simulates patient health metrics such as age, BMI, and glucose level\n",
#     "data = {\n",
#     "    'age': [25, 45, 33, 50, 62],\n",
#     "    'bmi': [22.2, 30.5, 28.0, 35.1, 26.3],\n",
#     "    'glucose': [85, 160, 120, 200, 140],\n",
#     "    'diabetes': [0, 1, 0, 1, 1]  # 0=No Diabetes, 1=Diabetes\n",
#     "}\n",
#     "\n",
#     "# Create a Pandas DataFrame from the sample data\n",
#     "df = pd.DataFrame(data)"
#    ]
#   },
#   {
#    "cell_type": "code",
#    "execution_count": null,
#    "metadata": {},
#    "outputs": [],
#    "source": [
#     "# Step 3: Prepare the data for training\n",
#     "# Separate features (X) from the target variable (y)\n",
#     "X = df.drop('diabetes', axis=1)  # Features: age, bmi, glucose\n",
#     "y = df['diabetes']  # Target variable: diabetes (0 or 1)\n",
#     "\n",
#     "# Split the dataset into training and testing sets\n",
#     "X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=42)  # 60% training, 40% testing"
#    ]
#   },
#   {
#    "cell_type": "code",
#    "execution_count": null,
#    "metadata": {},
#    "outputs": [],
#    "source": [
#     "# Step 4: Train the Decision Tree Classifier\n",
#     "# Create a Decision Tree Classifier model\n",
#     "model = DecisionTreeClassifier(random_state=42)  # Use a random state for reproducibility\n",
#     "\n",
#     "# Train the model on the training data\n",
#     "model.fit(X_train, y_train)"
#    ]
#   },
#   {
#    "cell_type": "code",
#    "execution_count": null,
#    "metadata": {},
#    "outputs": [],
#    "source": [
#     "# Step 5: Evaluate the model\n",
#     "# Make predictions on the test data\n",
#     "preds = model.predict(X_test)\n",
#     "\n",
#     "# Calculate the accuracy of the model\n",
#     "acc = accuracy_score(y_test, preds)\n",
#     "\n",
#     "# Print the accuracy\n",
#     "print(f\"🩺 Diagnosis Accuracy: {acc*100:.2f}% \")"
#    ]
#   },
#   {
#    "cell_type": "markdown",
#    "metadata": {},
#    "source": [
#     "### ✅ Key Takeaways:\n",
#     "- Machine learning can be used to predict diseases based on health metrics.\n",
#     "- The Decision Tree Classifier is a simple and interpretable algorithm for classification tasks.\n",
#     "- Accuracy is a common metric to evaluate classification models.\n",
#     "\n",
#     "Feel free to experiment with different datasets, features, or algorithms to improve the model's performance!"
#    ]
#   }
#  ],
#  "metadata": {
#   "kernelspec": {
#    "display_name": "Python 3",
#    "language": "python",
#    "name": "python3"
#   },
#   "language_info": {
#    "name": "python",
#    "version": ""
#   }
#  },
#  "nbformat": 4,
#  "nbformat_minor": 5
# }
