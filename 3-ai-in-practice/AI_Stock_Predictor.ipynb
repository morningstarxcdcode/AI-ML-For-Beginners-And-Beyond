# %%
{
 "cells": [
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "# 📈 AI in Finance: Predicting Stock Prices with Linear Regression\n",
    "\n",
    "Train a model to predict stock prices using linear regression.\n",
    "\n",
    "### 🎯 Objective:\n",
    "- Build a Linear Regression model to predict stock prices.\n",
    "- Visualize the model's predictions against actual prices."
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "# Step 1: Import necessary libraries\n",
    "import pandas as pd\n",
    "import numpy as np\n",
    "import matplotlib.pyplot as plt\n",
    "from sklearn.linear_model import LinearRegression"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "# Step 2: Create fake stock data\n",
    "# This dataset simulates stock prices over a few days\n",
    "days = np.array([1, 2, 3, 4, 5]).reshape(-1, 1)  # Days\n",
    "prices = np.array([100, 102, 104, 103, 108])  # Prices"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "# Step 3: Train the Linear Regression model\n",
    "# Create a Linear Regression model\n",
    "model = LinearRegression()\n",
    "\n",
    "# Train the model on the data\n",
    "model.fit(days, prices)"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "# Step 4: Predict future stock price\n",
    "# Predict the stock price for Day 6\n",
    "future_day = [[6]]  # Day 6\n",
    "predicted_price = model.predict(future_day)\n",
    "\n",
    "# Print the predicted price\n",
    "print(f\"📉 Predicted price on Day 6: ${predicted_price[0]:.2f}\")"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "# Step 5: Visualize the results\n",
    "# Plot the actual prices and the predicted price\n",
    "plt.plot(days, prices, marker='o', label='Actual Prices')  # Actual prices\n",
    "plt.plot(future_day, predicted_price, 'rx', label='Predicted Day 6')  # Predicted price\n",
    "plt.xlabel('Day')\n",
    "plt.ylabel('Price')\n",
    "plt.legend()\n",
    "plt.title('Simple Stock Predictor')\n",
    "plt.show()"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "### ✅ Key Takeaways:\n",
    "- Linear regression can be used to predict stock prices.\n",
    "- Visualizing the data helps understand the model's predictions.\n",
    "- This is a simplified example and real-world stock prediction is much more complex.\n",
    "\n",
    "Feel free to experiment with more complex models or larger datasets for more accurate predictions!"
   ]
  }
 ],
 "metadata": {
  "kernelspec": {
   "display_name": "Python 3",
   "language": "python",
   "name": "python3"
  },
  "language_info": {
   "name": "python",
   "version": ""
  }
 },
 "nbformat": 4,
 "nbformat_minor": 5
}
