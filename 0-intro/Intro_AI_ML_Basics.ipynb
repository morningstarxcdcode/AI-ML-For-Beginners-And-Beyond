# %%
{
 "cells": [
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "# 🤖 Introduction to AI & ML (In 10 Minutes!)\n",
    "\n",
    "Welcome to your **AI/ML learning journey**! In this notebook, we'll break down AI and ML into super simple concepts:\n",
    "\n",
    "### 🔍 What is Artificial Intelligence (AI)?\n",
    "- Mimics human intelligence\n",
    "- Thinks, learns, makes decisions\n",
    "- Examples: Siri, Google Translate, Self-driving cars\n",
    "\n",
    "### 📊 What is Machine Learning (ML)?\n",
    "- Subset of AI\n",
    "- Learns from **data**, not rules\n",
    "- Example: Predicting house prices, spam detection\n",
    "\n",
    "---\n",
    "\n",
    "### 📚 Types of Machine Learning\n",
    "- **Supervised Learning** 🧠 (with labels)\n",
    "  - Example: Email spam detection\n",
    "- **Unsupervised Learning** 🔍 (no labels)\n",
    "  - Example: Customer segmentation\n",
    "- **Reinforcement Learning** 🕹️ (reward-based)\n",
    "  - Example: Game playing bots\n",
    "\n",
    "---\n",
    "\n",
    "### ✅ Key Terms to Remember\n",
    "| Term | Meaning |\n",
    "|------|---------|\n",
    "| Dataset | Collection of data |\n",
    "| Model | Mathematical representation |\n",
    "| Training | Learning from data |\n",
    "| Testing | Evaluating accuracy |\n",
    "\n",
    "---\n",
    "\n",
    "### 🔧 Mini Task: Try this in the next notebook\n",
    "We'll load a dataset, train a simple ML model, and predict something. 🚀"
   ]
  }
 ],
 "metadata": {
  "kernelspec": {
   "display_name": "Python 3",
   "language": "python",
   "name": "python3"
  },
  "language_info": {
   "name": "python"
  }
 },
 "nbformat": 4,
 "nbformat_minor": 2
}
